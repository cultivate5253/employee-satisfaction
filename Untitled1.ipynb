# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\kakizaw\.cisco\anacon\python.exe -m pip install --upgrade pip' command.

# %%
from selenium import webdriver

# %%
browser=webdriver.Chrome()

# %%
browser.get('https://www.vorkers.com/award/')

# %%
elems = browser.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div[1]/div/div[3]/div[1]/div/div[1]/div[2]/div[2]/p[1]/a')
# Out:
# C:\Users\kakizaw\AppData\Local\Temp/ipykernel_10364/3128506948.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   elems = browser.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div[1]/div/div[3]/div[1]/div/div[1]/div[2]/div[2]/p[1]/a')

# %%
elem.text
# Out:
# 'P&Gジャパン合同会社（旧：プロクター・アンド・ギャンブル・ジャパン株式会社）'

# %%
elems=browser.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div[1]/div/div[3]/div[1]/div/')
# Out:
# C:\Users\kakizaw\AppData\Local\Temp/ipykernel_10364/2319502742.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   elems=browser.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div[1]/div/div[3]/div[1]/div/')
# ---------------------------
# InvalidSelectorExceptionTraceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10364/2319502742.py in <module>
# ----> 1 elems=browser.find_elements_by_xpath('/html/body/div/div[2]/div[2]/div[1]/div/div[3]/div[1]/div/')
#
# ~\.cisco\anacon\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_xpath(self, xpath)
#     541             stacklevel=2,
#     542         )
# --> 543         return self.find_elements(by=By.XPATH, value=xpath)
#     544
#     545     def find_element_by_link_text(self, link_text) -> WebElement:
#
# ~\.cisco\anacon\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
# ...

# %%
elems[1].text
# Out:
# ---------------------------
# IndexErrorTraceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10364/2271994237.py in <module>
# ----> 1 elems[1].text
#
# IndexError: list index out of range

# %%
len(elems)
# Out:
# 1

# %%
elems=browser.find_elements_by_class_name('company_name')
# Out:
# C:\Users\kakizaw\AppData\Local\Temp/ipykernel_10364/2199973123.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   elems=browser.find_elements_by_class_name('company_name')

# %%
len(elems)
# Out:
# 50

# %%
elems[0].text
# Out:
# 'P&Gジャパン合同会社（旧：プロクター・アンド・ギャンブル・ジャパン株式会社）'

# %%
companys=[]
for elem in elems:
    company=elem.text
    companys.append(company)

# %%
companys
# Out:
# ['P&Gジャパン合同会社（旧：プロクター・アンド・ギャンブル・ジャパン株式会社）',
#  '株式会社セールスフォース・ドットコム',
#  'プルデンシャル生命保険株式会社',
#  '伊藤忠商事株式会社',
#  'ソニーグループ株式会社（旧：ソニー株式会社）',
#  '株式会社ベイカレント・コンサルティング',
#  'アビームコンサルティング株式会社',
#  '旭化成株式会社（化学）',
#  '三井物産株式会社',
#  '三菱商事株式会社',
#  'アクセンチュア株式会社',
#  '株式会社クイック（人材）',
#  'PwCコンサルティング合同会社',
#  '東京海上日動火災保険株式会社',
#  '株式会社キーエンス',
#  '日本アイ・ビー・エム株式会社（IBM）',
#  '株式会社野村総合研究所',
#  'デロイト トーマツ コンサルティング合同会社',
#  '株式会社村田製作所',
#  '株式会社電通',
#  'アステラス製薬株式会社',
#  '株式会社ディー・エヌ・エー(DeNA)',
#  '味の素株式会社',
#  'オリックス株式会社',
#  '住友商事株式会社',
#  'Apple Japan合同会社',
#  'スターバックス コーヒー ジャパン株式会社',
#  'レイス株式会社（人材）',
#  'エン・ジャパン株式会社',
#  'トヨタ自動車株式会社',
#  '楽天グループ株式会社（旧：楽天株式会社）',
#  '双日株式会社',
#  '株式会社サイバーエージェント',
#  'アマゾンジャパン合同会社',
#  '株式会社マルハン',
#  '野村證券株式会社',
#  '株式会社三井住友銀行',
#  '株式会社ビズリーチ',
#  '株式会社オープンハウス',
#  '花王株式会社',
#  'KPMGコンサルティング株式会社',
#  '富士フイルム株式会社',
#  '大和証券株式会社',
#  '鹿島建設株式会社',
#  '株式会社キャリアデザインセンター',
#  '千代田化工建設株式会社',
#  '株式会社博報堂',
#  '豊田通商株式会社',
#  'ほけんの窓口グループ株式会社',
#  'LINE株式会社']

# %%
elems=browser.find_elements_by_class_name('score')
# Out:
# C:\Users\kakizaw\AppData\Local\Temp/ipykernel_10364/2351365371.py:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   elems=browser.find_elements_by_class_name('score')

# %%
len(elems)
# Out:
# 50

# %%
scores=[]
for elem in elems:
    score=elem.text
    scores.append(score)

# %%
scores
# Out:
# ['4.63',
#  '4.58',
#  '4.53',
#  '4.37',
#  '4.36',
#  '4.36',
#  '4.36',
#  '4.36',
#  '4.29',
#  '4.28',
#  '4.27',
#  '4.25',
#  '4.23',
#  '4.23',
#  '4.23',
#  '4.21',
#  '4.20',
#  '4.20',
#  '4.19',
#  '4.18',
#  '4.17',
#  '4.17',
#  '4.09',
#  '4.07',
#  '4.03',
#  '4.02',
#  '4.00',
#  '4.00',
#  '3.99',
#  '3.99',
#  '3.98',
#  '3.95',
#  '3.95',
#  '3.94',
#  '3.93',
#  '3.91',
#  '3.90',
#  '3.89',
#  '3.88',
#  '3.88',
#  '3.88',
#  '3.86',
#  '3.84',
#  '3.82',
#  '3.82',
#  '3.80',
#  '3.80',
#  '3.80',
#  '3.80',
#  '3.78']

# %%
list=zip(companys,scores)

# %%
import pandas as pd

# %%
df=pd.DataFrame(list)

# %%
df.columns=['会社名','働き甲斐スコア']

# %%
df
# Out:
#                                         会社名 働き甲斐スコア
# 0   P&Gジャパン合同会社（旧：プロクター・アンド・ギャンブル・ジャパン株式会社）    4.63
# 1                        株式会社セールスフォース・ドットコム    4.58
# 2                           プルデンシャル生命保険株式会社    4.53
# 3                                 伊藤忠商事株式会社    4.37
# 4                    ソニーグループ株式会社（旧：ソニー株式会社）    4.36
# 5                       株式会社ベイカレント・コンサルティング    4.36
# 6                          アビームコンサルティング株式会社    4.36
# 7                               旭化成株式会社（化学）    4.36
# 8                                  三井物産株式会社    4.29
# 9                                  三菱商事株式会社    4.28
# 10                              アクセンチュア株式会社    4.27
# 11                             株式会社クイック（人材）    4.25
# 12                          PwCコンサルティング合同会社    4.23
# 13                           東京海上日動火災保険株式会社    4.23
# 14                                株式会社キーエンス    4.23
# 15                      日本アイ・ビー・エム株式会社（IBM）    4.21
# 16                              株式会社野村総合研究所    4.20
# ...

# %%
df2=df.iloc[1]

# %%
df2=

# %%
df2
